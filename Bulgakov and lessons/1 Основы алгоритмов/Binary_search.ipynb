# %%
# Бинарный поиск в отсортированном по возрастанию массиве
# Будет возращать индекс искомого элемента

def binary_search(descending_arr, search_for):
  smallest_index = 0 #biggest_index
  biggest_index = len(nums) - 1 #smallest_index
  searched_num_index = None

  while (smallest_index <= biggest_index) and (searched_num_index == None): #start searching cycle
    mid = (smallest_index + biggest_index) // 2 #сounting middle

    if nums[mid] == search_for:
      searched_num_index = mid
    else:
      if search_for < nums[mid]: #Search in left part
        biggest_index = mid - 1
      else: #Search in right part
        smallest_index = mid + 1 

  return searched_num_index


nums = [0, 1, 2, 3, 4, 5, 6, 7, 8, 22]

print(binary_search(nums, 22))
# Out:
# 9
